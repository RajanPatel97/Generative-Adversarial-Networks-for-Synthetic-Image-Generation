# %% [markdown]
# # Deep Convolutional GAN (DCGAN) with MNIST
#
# This is a follow-up on [gan_mnist.ipynb](gan_mnist.ipynb).  It uses deep convolutional networks in the generator and the discriminator.

# %%
import numpy as np
from scipy.io import loadmat
import keras
import keras.backend as K
from keras.layers import Dense, Activation, LeakyReLU, BatchNormalization
from keras.layers import Conv2D, Conv2DTranspose, Reshape, Flatten
from keras.models import Sequential
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading MNIST Dataset

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

assert(len(X_train) == len(y_train))
assert(len(X_test) == len(y_test))

print("Image Shape: {}".format(X_train[0].shape))
print("Training Set:   {} samples".format(len(X_train)))
print("Test Set:       {} samples".format(len(X_test)))
# Out:
# Image Shape: (28, 28)
# Training Set:   60000 samples
# Test Set:       10000 samples

# %%
import pdb
import random


index = random.randint(0, len(X_train))
image = X_train[index].squeeze()

plt.figure(figsize=(2,2))
plt.imshow(image)
print("Label of the image is:%d"%y_train[index])
# Out:
# Label of the image is:7

# %% [markdown]
# We only use the images not the categorical labels.

# %%
plt.figure(figsize=(5, 4))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preprocessing and Deprocessing
#
# As usual, we need preprocessing and later deprocessing of the images.
#
# As we will see later on, the generator is using `tanh` activation, for which we need to preprocess the image data into the range between -1 and 1.

# %%
def preprocess(x):    
    x = x.reshape(-1, 28, 28, 1) # 28,28,1
    x = np.float64(x)
    x = (x / 255 - 0.5) * 2
    x = np.clip(x, -1, 1)
    return x

def deprocess(x):
    x = (x / 2 + 1) * 255
    x = np.clip(x, 0, 255)
    x = np.uint8(x)
    x = x.reshape(28, 28)
    return x

# %% [markdown]
# Apply the preprocessing on the train and test images (and they are the real images as oppose to the generated images).

# %%
X_train_real = preprocess(X_train)
X_test_real  = preprocess(X_test)

# %% [markdown]
# ## Generator
#
# The original DCGAN paper [[3]](#ref3) proposes the following generator network architecture.
#
# <img src='../images/dcgan_svhn/generator.png' width='70%'>
#
# In this notebook, I used smaller networks than what the original paper [[3]](#ref3) uses as our image size is 28x28 and it has only 1 channel.
#
# The generator takes a latent sample of 100 random numbers and generates a 28x28 image with 1 channel.
#
# The first layer accepts 784 data points just like [gan_mnist.ipynb](gan_mnist.ipynb).  Then, it reshapes the data into 7x7 with 16 filters.  Afterwards, two transposed convolution layers will up-sample the data shape into 28x28.
#
# For the details of the tranposed convolution, see [transposed_convolution.ipynb](transposed_convolution.ipynb).

# %%
def make_generator(input_size, leaky_alpha):
    # generates images in (28,28,1)
    return Sequential([
        # FC 1: 7,7,16
        Dense(784, input_shape=(input_size,)),
        Reshape(target_shape=(7, 7, 16)),
        BatchNormalization(),
        LeakyReLU(alpha=leaky_alpha),
        
        # Conv 1: 14,14,32
        Conv2DTranspose(32, kernel_size=5, strides=2, padding='same'), 
        BatchNormalization(),
        LeakyReLU(alpha=leaky_alpha),
        
        # Conv 2: 28,28,1
        Conv2DTranspose(1, kernel_size=5, strides=2, padding='same'),
        Activation('tanh')
    ])

# %% [markdown]
# ## Discriminator

# %% [markdown]
# The discriminator is a classifier to tell if the input image is real or fake.
#
# It is a convolutional neural network that takes a 28x28 image with 1 channel.  The values in the image is expected to be between -1 and 1.
#
# The activation of the output layer is `sigmoid` and the discriminator outputs a probability of the image being real.
#
# In [gan_mnist.ipynb](gan_mnist.ipynb), I used a fully connected layer with 784 (=28x28) neurons.  To make this discriminator comparable, I use the same number of neurons in the last fully connected hidden layer, and then added convolution layers beforehands.
#
# Note: using the decreasing number of filters may be a bit unusual but I did this to make the discriminator network and the generator network to have same kind of increase in the number of convolutional network neurons (hopefully keeping their power in balance).

# %%
def make_discriminator(leaky_alpha):
    # classifies images in (28,28,1)
    return Sequential([        
        # Conv 1: 14,14,32
        Conv2D(32, kernel_size=5, strides=2, padding='same', input_shape=(28,28,1)),
        LeakyReLU(alpha=leaky_alpha),
        
        # Conv 2: 7,7,16
        Conv2D(16, kernel_size=5, strides=2, padding='same'),   
        BatchNormalization(),
        LeakyReLU(alpha=leaky_alpha),
        
        # FC 1
        Flatten(),
        Dense(784),
        BatchNormalization(),
        LeakyReLU(alpha=leaky_alpha),
        
        # Output
        Dense(1),
        Activation('sigmoid')        
    ])

# %% [markdown]
# ### About Batch Normalization
#
# As for the batch normalization, it was applied to most of the layers but not all.  The below is a quote from the original DCGAN paper [[3]](#ref3).
#
# > Directly applying batchnorm to all layers, however, resulted in sample oscillation and model instability. This was avoided by not applying batchnorm to the generator output layer and the discriminator input layer.

# %% [markdown]
# ## DCGAN
#
# We connect the generator and the discriminator to make a DCGAN.
#
# The input to the DCGAN is a latent sample.  The generator inside DCGAN produces an image which is fed into the discriminator inside the DCGAN.  So, the output of DCGAN is the probability of the generated image being real.

# %%
# beta_1 is the exponential decay rate for the 1st moment estimates in Adam optimizer
def make_DCGAN(sample_size, 
               g_learning_rate,
               g_beta_1,
               d_learning_rate,
               d_beta_1,
               leaky_alpha):
    # clear first
    K.clear_session()
    
    # generator
    generator = make_generator(sample_size, leaky_alpha)

    # discriminator
    discriminator = make_discriminator(leaky_alpha)
    discriminator.compile(optimizer=Adam(lr=d_learning_rate, beta_1=d_beta_1), loss='binary_crossentropy')
    
    # GAN
    gan = Sequential([generator, discriminator])
    gan.compile(optimizer=Adam(lr=g_learning_rate, beta_1=g_beta_1), loss='binary_crossentropy')
    
    return gan, generator, discriminator

# %% [markdown]
# ## Training DCGAN
#
# The below is a function to generate latent samples.

# %%
def make_latent_samples(n_samples, sample_size):
    #return np.random.uniform(-1, 1, size=(n_samples, sample_size))
    return np.random.normal(loc=0, scale=1, size=(n_samples, sample_size))

# %% [markdown]
# The below is a function to set the discriminator to trainable or non-trainable.

# %%
def make_trainable(model, trainable):
    for layer in model.layers:
        layer.trainable = trainable

# %% [markdown]
# The below is a function to create a batch of labels.

# %%
def make_labels(size):
    return np.ones([size, 1]), np.zeros([size, 1])

# %% [markdown]
# The below is to show the losses.

# %%
def show_results(losses):
    labels = ['Classifier', 'Discriminator', 'Generator']
    losses = np.array(losses)    
    
    fig, ax = plt.subplots()
    plt.plot(losses.T[0], label='Discriminator Loss')
    plt.plot(losses.T[1], label='Generator Loss')
    plt.title("Training Losses")
        plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# The below is to show the generated images.

# %%
def show_images(generated_images):
    n_images = len(generated_images)
    rows = 4
    cols = n_images//rows
    
    plt.figure(figsize=(cols, rows))
    for i in range(n_images):
        img = deprocess(generated_images[i])
        plt.subplot(rows, cols, i+1)
        plt.imshow(img, cmap='gray')
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout()
    plt.show()

# %% [markdown]
# The training DCGAN is essentially the same as training a simple GAN in [gan_mnist.ipynb](gan_mnist.ipynb).
#
# * set the discriminator trainable
# * train the discriminator with real images with the label smoothing   (labels=1-smooth)
# * train the discriminator with fake images generated by the generator (labels=0)
# * set the discriminator non-trainable
# * train the DCGAN with generated images (labels=1)
#
# We repeat this process many times until the discriminator loss and the generator loss stabilizes.

# %%
def train(
    g_learning_rate,   # learning rate for the generator
    g_beta_1,          # the exponential decay rate for the 1st moment estimates in Adam optimizer
    d_learning_rate,   # learning rate for the discriminator
    d_beta_1,          # the exponential decay rate for the 1st moment estimates in Adam optimizer
    leaky_alpha,
    smooth=0.1,        # label smoothing
    sample_size=100,   # latent sample size (i.e. 100 random numbers)
    epochs=1000,
    batch_size=128,    # train batch size
    eval_size=16,      # evaluate size
    show_details=True):
    
    # labels for the batch size and the test size
    y_train_real, y_train_fake = make_labels(batch_size)
    y_eval_real,  y_eval_fake  = make_labels(eval_size)

    # create a GAN, a generator and a discriminator
    gan, generator, discriminator = make_DCGAN(
        sample_size, 
        g_learning_rate, 
        g_beta_1,
        d_learning_rate,
        d_beta_1,
        leaky_alpha)

    losses = []
    for e in range(epochs):
        for i in range(len(X_train_real)//batch_size):
            # real MNIST digit images
            X_batch_real = X_train_real[i*batch_size:(i+1)*batch_size]

            # latent samples and the generated digit images
            latent_samples = make_latent_samples(batch_size, sample_size)
            X_batch_fake = generator.predict_on_batch(latent_samples)

            # train the discriminator to detect real and fake images
            make_trainable(discriminator, True)
            discriminator.train_on_batch(X_batch_real, y_train_real * (1 - smooth))
            discriminator.train_on_batch(X_batch_fake, y_train_fake)

            # train the generator via GAN
            make_trainable(discriminator, False)
            gan.train_on_batch(latent_samples, y_train_real)

        # evaluate
        X_eval_real = X_test_real[np.random.choice(len(X_test_real), eval_size, replace=False)]

        latent_samples = make_latent_samples(eval_size, sample_size)
        X_eval_fake = generator.predict_on_batch(latent_samples)

        d_loss  = discriminator.test_on_batch(X_eval_real, y_eval_real)
        d_loss += discriminator.test_on_batch(X_eval_fake, y_eval_fake)
        g_loss  = gan.test_on_batch(latent_samples, y_eval_real) # we want the fake to be realistic!

        losses.append((d_loss, g_loss))

        print("Epoch:{:>3}/{} Discriminator Loss:{:>7.4f} Generator Loss:{:>7.4f}".format(
            e+1, epochs, d_loss, g_loss))
        
        if show_details and (e+1)%10==0:
            show_images(X_eval_fake)
    if show_details:
        show_results(losses)
    return generator

# %%
train(g_learning_rate=0.0001, g_beta_1=0.9, d_learning_rate=0.001, d_beta_1=0.9, leaky_alpha=0.01);
# Out:
# /home/user/enter/envs/CV/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epo
site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch:  1/1000 Discriminator Loss: 8.7052 Generator Loss: 5.2384
# Epoch:  2/1000 Discriminator Loss:11.4510 Generator Loss: 8.4952
# Epoch:  3/1000 Discriminator Loss:14.8430 Generator Loss:12.9426
# Epoch:  4/1000 Discriminator Loss: 7.2389 Generator Loss: 6.6641
# Epoch:  5/1000 Discriminator Loss:12.5973 Generator Loss:11.5196
# Epoch:  6/1000 Discriminator Loss: 8.4047 Generator Loss: 8.6528
# Epoch:  7/1000 Discriminator Loss:10.2385 Generator Loss:11.4316
# Epoch:  8/1000 Discriminator Loss:10.6009 Generator Loss:10.8923
# Epoch:  9/1000 Discriminator Loss:14.5392 Generator Loss:13.8777
# Epoch: 10/1000 Discriminator Loss:14.5195 Generator Loss:13.9399
# Epoch: 11/1000 Discriminator Loss: 8.5111 Generator Loss: 8.5406
# Epoch: 12/1000 Discriminator Loss: 8.3858 Generator Loss: 7.2273
# Epoch: 13/1000 Discriminator Loss:15.9718 Generator Loss:16.0358
# Epoch: 14/1000 Discriminator Loss:15.4631 Generator Loss:15.2891
# Epoch: 15/1000 Discriminator Loss:10.7614 Generator Loss:11.5505
# Epoch: 16/1000 Discriminator Loss:11.6632 Generator Loss:12.1512
# Epoch: 17/1000 Discriminator Loss:16.1181 Generator Loss:15.9170
# Epoch: 18/1000 Discriminator Loss:13.6665 Generator Loss:14.4221
# Epoch: 19/1000 Discriminator Loss:13.5380 Generator Loss:14.0654
# Epoch: 20/1000 Discriminator Loss:15.5045 Generator Loss:15.8526
# Epoch: 21/1000 Discriminator Loss:12.1524 Generator Loss:12.4565
# Epoch: 22/1000 Discriminator Loss:15.6297 Generator Loss:15.5429
# Epoch: 23/1000 Discriminator Loss:15.3326 Generator Loss:15.6898
# Epoch: 24/1000 Discriminator Loss: 9.9626 Generator Loss: 9.8932
# Epoch: 25/1000 Discriminator Loss:11.0745 Generator Loss:10.9188
# Epoch: 26/1000 Discriminator Loss:10.2252 Generator Loss:11.1010
# Epoch: 27/1000 Discriminator Loss:12.8485 Generator Loss:10.4739
# Epoch: 28/1000 Discriminator Loss:14.2906 Generator Loss:12.9628
# Epoch: 29/1000 Discriminator Loss:10.0481 Generator Loss:10.2963
# Epoch: 30/1000 Discriminator Loss:13.7301 Generator Loss:14.5989
# Epoch: 31/1000 Discriminator Loss:12.6175 Generator Loss:13.1861
# Epoch: 32/1000 Discriminator Loss:11.5850 Generator Loss:12.5001
# Epoch: 33/1000 Discriminator Loss:13.3627 Generator Loss:12.8392
# Epoch: 34/1000 Discriminator Loss: 5.8021 Generator Loss: 6.1711
# Epoch: 35/1000 Discriminator Loss: 7.3021 Generator Loss: 8.9852
# Epoch: 36/1000 Discriminator Loss:10.9537 Generator Loss:11.8860
# Epoch: 37/1000 Discriminator Loss: 7.2749 Generator Loss: 7.0962
# Epoch: 38/1000 Discriminator Loss: 5.1619 Generator Loss: 6.3392
# Epoch: 39/1000 Discriminator Loss:13.5422 Generator Loss:14.1274
# Epoch: 40/1000 Discriminator Loss:10.1376 Generator Loss: 9.4380
# Epoch: 41/1000 Discriminator Loss: 5.1196 Generator Loss: 5.1354
# Epoch: 42/1000 Discriminator Loss: 9.1143 Generator Loss: 8.9914
# Epoch: 43/1000 Discriminator Loss:11.8299 Generator Loss:11.8548
# Epoch:121/1000 Discriminator Loss: 5.4796 Generator Loss: 6.0114
# Epoch:122/1000 Discriminator Loss: 3.4239 Generator Loss: 4.1779
# Epoch:123/1000 Discriminator Loss: 6.8620 Generator Loss: 6.4236
# Epoch:124/1000 Discriminator Loss: 1.8355 Generator Loss: 2.6014
# Epoch:125/1000 Discriminator Loss: 3.2478 Generator Loss: 4.3282
# Epoch:126/1000 Discriminator Loss: 6.1209 Generator Loss: 8.0590
# Epoch:127/1000 Discriminator Loss: 5.6703 Generator Loss: 6.9661
# Epoch:128/1000 Discriminator Loss: 4.8475 Generator Loss: 6.1479
# Epoch:129/1000 Discriminator Loss: 6.5274 Generator Loss: 6.6377
# Epoch:130/1000 Discriminator Loss: 4.4731 Generator Loss: 6.1469
# Epoch:131/1000 Discriminator Loss: 4.2454 Generator Loss: 4.7278
# Epoch:132/1000 Discriminator Loss: 3.9691 Generator Loss: 5.1417
# Epoch:133/1000 Discriminator Loss: 6.7297 Generator Loss: 7.9889
# Epoch:134/1000 Discriminator Loss: 6.6344 Generator Loss: 7.9590
# Epoch:135/1000 Discriminator Loss: 6.7709 Generator Loss: 7.7967
# Epoch:136/1000 Discriminator Loss: 4.8891 Generator Loss: 6.2743
# Epoch:137/1000 Discriminator Loss: 8.0871 Generator Loss: 8.3978
# Epoch:138/1000 Discriminator Loss: 2.7480 Generator Loss: 4.0067
# Epoch:139/1000 Discriminator Loss: 9.2444 Generator Loss: 9.0761
# Epoch:140/1000 Discriminator Loss:14.2087 Generator Loss:13.9959
# Epoch:141/1000 Discriminator Loss: 8.2884 Generator Loss: 8.0674
# Epoch:142/1000 Discriminator Loss: 5.6835 Generator Loss: 7.1064
# Epoch:143/1000 Discriminator Loss: 6.5979 Generator Loss: 7.6771
# Epoch:144/1000 Discriminator Loss: 8.8399 Generator Loss: 9.9089
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c0b995d94f99> in <module>
# ----> 1 train(g_learning_rate=0.0001, g_beta_1=0.9, d_learning_rate=0.001, d_beta_1=0.9, leaky_alpha=0.02);
#
# <ipython-input-15-656658c8a006> in train(g_learning_rate, g_beta_1, d_learning_rate, d_beta_1, leaky_alpha, smooth, sample_size, epochs, batch_size, eval_size, show_details)
#      42             # train the generator via GAN
#      43             make_trainable(discriminator, False)
# ---> 44             gan.train_on_batch(latent_samples, y_train_real)
#      45
#      46         # evaluate
#
# ~/enter/envs/CV/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/enter/envs/CV/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/enter/envs/CV/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/enter/envs/CV/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# I used leaky_relu=0.2 for the above experiment.  The losses oscillates more.  The generated images look as good.

# %% [markdown]
# ## References
#
# <a id="ref1"></a>
# ### [1] MNIST dataset
#
# Yann LeCun
#
# http://yann.lecun.com/exdb/mnist/
#
# <a id="ref2"></a>
# ### [2] Deep Convolutional GANs
#
# Udacity
#
# https://github.com/udacity/deep-learning/blob/master/dcgan-svhn/DCGAN.ipynb
#
# <a id="ref3"></a>
# ### [3] Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks
#
# Alec Radford & Luke Metz (indico Research), Soumith Chintala (Facebook AI Research)
#
# https://arxiv.org/pdf/1511.06434.pdf
